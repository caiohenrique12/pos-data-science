# %%
import numpy as np
import plotly.express as px
from sklearn.linear_model import LinearRegression
import pandas_datareader.data as pdr
import datetime
import pandas as pd

# %%
aapl = pdr.get_data_yahoo('AAPL')
aapl.to_csv("/home/dev/Projetos/pos-data-science/aed/aapl.csv")
df = pd.read_csv('/home/dev/Projetos/pos-data-science/aed/aapl.csv')
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 1     2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2     2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 3     2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# 4     2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
# ...          ...         ...         ...         ...         ...          ...
# 2424  2019-08-21  213.649994  211.600006  212.990005  212.639999   21535400.0
# 2425  2019-08-22  214.440002  210.750000  213.190002  212.460007   22253700.0
# 2426  2019-08-23  212.050003  201.000000  209.429993  202.639999   46818000.0
# 2427  2019-08-26  207.190002  205.059998  205.860001  206.490005   26043600.0
# 2428  2019-08-27  208.550003  203.529999  207.860001  204.160004   25873300.0
#
#        Adj Close
# ...

# %%
fig = px.line(df, x='Date', y='High')
fig.show()
# Out:
# <div>
#
#
#             <div id="c1d1ba14-a265-4708-9bbb-f495377fef97" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1d1ba14-a265-4708-9bbb-f495377fef97")) {
#                     Plotly.newPlot(
#                         'c1d1ba14-a265-4708-9bbb-f495377fef97',
# ...
