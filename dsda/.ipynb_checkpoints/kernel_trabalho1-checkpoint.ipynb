# %% [markdown]
# # Exercícios Programação Data Science - Utilizando Pandas
# ---

# %%
import os
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# print(os.listdir("../input"))

# %% [markdown]
# ## EX01
#
# * Carregue para um DataFrame a lista de municípios de fronteira do Brasil utilizando o arquivo "arquivos/arq_municipios_fronteiricos.csv".

# %%
# Variavel contendo o nome do arquivo
# Complete o código abaixo para realizar a leitura do arquivo
# o arquivo utiliza tabulação como separador
# dentro de strings a tabulação é representada como \t
df = pd.read_csv("arq_municipios_fronteiricos.csv", na_values='ni')
df.head()

# Visualize as 5 primeiras linhas do DataFrame
# Out:
#                    Município             Estado  Área territorial  \
# 0                 1 – Aceguá  Rio Grande do Sul             1.550
# 1             2 – Acrelândia               Acre             1.575
# 2                3 – Alecrim  Rio Grande do Sul           315.000
# 3               4 – Almeirim               Pará            72.960
# 4  5 – Alta Floresta d'Oeste           Rondônia             7.067
#
#    População (IBGE/2007) Densidade demográfica (hab/km2) PIB (IBGE/2005  \
# 0                  4.138                            2,66     71.638.000
# 1                 11.520                            7,31    114.350.000
# 2                  7.357                           23,35     44.373.000
# 3                 30.903                            0,42    462.258.000
# 4                 23.857                            3,37    186.812.000
#
#   PIB per capita (R$) IDH/2000
# 0              17.266      NaN
# 1               9.986    0,680
# 2               5.944    0,743
# 3              13.485    0,745
# 4               6.525    0,715

# %% [markdown]
# * Realize um tratamento na coluna Município para remover os números e hífens.
#     * primeiro crie uma função recebe uma string com o nome do município, realiza a remoção dos números e hifens e retorna a nova string tratada
#     * faça os testes com a sua função até que o resultado esteja satisfatório
#     * passe a sua função como parâmetro para o método apply do DataFrame

# %%
# função que irá realizar o tratamento para um município
def tratar_nome_municipio(nome_municipio):
    #realize a limpeza
    nome_municipio_tratado = re.sub(r'([\d]* [–-] )(.*)', r'\2', nome_municipio)    
    return nome_municipio_tratado

# faça um teste de sua função para verificar se a transformação está correta
tratar_nome_municipio(df.Município[1])
# Out:
# 'Acrelândia'

# %%
# aplique a função utilizando o método apply
df['Município'] = df['Município'].apply(lambda x: tratar_nome_municipio(x))

# %%
# exiba todos os dados e verifique se o resultado está correto
df
# Out:
#                             Município             Estado  Área territorial  \
# 0                              Aceguá  Rio Grande do Sul             1.550
# 1                          Acrelândia               Acre             1.575
# 2                             Alecrim  Rio Grande do Sul           315.000
# 3                            Almeirim               Pará            72.960
# 4               Alta Floresta d'Oeste           Rondônia             7.067
# ..                                ...                ...               ...
# 117                         Tunápolis      Santa Cataria           133.000
# 118                          Uiramutã            Roraima             8.066
# 119                        Uruguaiana  Rio Grande do Sul             5.716
# 120  Vila Bela da Santíssima Trindade        Mato Grosso            13.631
# 121                            Xapuri               Acre             5.251
#
#      População (IBGE/2007) Densidade demográfica (hab/km2) PIB (IBGE/2005  \
# 0                    4.138                            2,66     71.638.000
# 1                   11.520                            7,31    114.350.000
# 2                    7.357                           23,35     44.373.000
# 3                   30.903                            0,42    462.258.000
# 4                   23.857                            3,37    186.812.000
# ..                     ...                             ...            ...
# 117                  4.650                           34,96     40.845.000
# 118                  7.403                            0,91     27.251.000
# 119                123.743                           21,64  1.187.038.000
# 120                 13.886                            1,01    116.908.000
# 121                 14.314                            2,72     82.377.000
#
#     PIB per capita (R$) IDH/2000
# 0                17.266      NaN
# 1                 9.986    0,680
# 2                 5.944    0,743
# 3                13.485    0,745
# 4                 6.525    0,715
# ..                  ...      ...
# 117               9.420    0,821
# 118               4.238    0,542
# 119               8.798    0,788
# 120               8.047    0,715
# 121               6.016    0,669
#
# [122 rows x 8 columns]

# %% [markdown]
# Algumas linhas ainda possuem hífen e números?

# %%
# problemas com caracteres são comuns
print(hex(ord('-'))) # código UTF8 do caracter (hexadecimal)
print(hex(ord('–'))) # código UTF8 do caracter (hexadecimal)
'-' == '–'
# Out:
# 0x2d
# 0x2013
# False

# %% [markdown]
# * HYPHEN-MINUS: __&#x2D;__
#     * https://www.fileformat.info/info/unicode/char/2d/index.htm
# * EN DASH: __&#x2013;__
#     * https://www.fileformat.info/info/unicode/char/2013/index.htm

# %%
# com todos os municípios devidamente tratados
# sobrescreva a coluna Município com os novos valores

# exiba as informações

# %% [markdown]
# ## EX02
#
# Ainda utilizando o DataFrame carregado no exercício anterior, verifique os tipos de dados das colunas do dataframe. Todos os dados numéricos deverão ser transformados para tipos numéricos.
#
# * utilize o método info() do DataFrame para saber detalhes dos tipos de dados das colunas
# * verifique se os números possuem os símbolos de decimal e separadores de milhar compatíveis com a linguagem. Se necessário, fazer as substituições pertinentes.

# %%
# verifique os tipos das colunas do DataFrame. Utilize o método info(): df_muni_front
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
# Município                          122 non-null object
# Estado                             122 non-null object
# Área territorial                   122 non-null float64
# População (IBGE/2007)              122 non-null float64
# Densidade demográfica (hab/km2)    122 non-null object
# PIB (IBGE/2005                     122 non-null object
# PIB per capita (R$)                122 non-null object
# IDH/2000                           104 non-null object
# dtypes: float64(2), object(6)
# memory usage: 7.8+ KB

# %%
df.head()
# Out:
#                Município             Estado  Área territorial  \
# 0                 Aceguá  Rio Grande do Sul             1.550
# 1             Acrelândia               Acre             1.575
# 2                Alecrim  Rio Grande do Sul           315.000
# 3               Almeirim               Pará            72.960
# 4  Alta Floresta d'Oeste           Rondônia             7.067
#
#    População (IBGE/2007) Densidade demográfica (hab/km2) PIB (IBGE/2005  \
# 0                  4.138                            2,66     71.638.000
# 1                 11.520                            7,31    114.350.000
# 2                  7.357                           23,35     44.373.000
# 3                 30.903                            0,42    462.258.000
# 4                 23.857                            3,37    186.812.000
#
#   PIB per capita (R$) IDH/2000
# 0              17.266      NaN
# 1               9.986    0,680
# 2               5.944    0,743
# 3              13.485    0,745
# 4               6.525    0,715

# %%
# faça a conversão do campo 'Área territorial'
def converter_para_float(texto):
    # faça as operações necessárias e 
    # devolva um objeto do tipo float
    # ou np.NaN (tipo Not a Number do numpy)
    t = texto.replace(' ','').replace('.','').replace(',','.');
    return float(t)

# aplique a função de conversão utilizando o método apply na coluna 'Área territorial'

# exiba alguns valores da com valores convertidos

# %%
# df.drop(df['IDH/2000'] == 'ni', axis=1)
df = df.dropna()
df['IDH/2000'].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# Name: IDH/2000, Length: 104, dtype: bool

# %%
# substitua a coluna pelos valores convertidos
df['Densidade demográfica (hab/km2)'] = df['Densidade demográfica (hab/km2)'].apply(lambda x: converter_para_float(x))
df['PIB (IBGE/2005'] = df['PIB (IBGE/2005'].apply(lambda x: converter_para_float(x))
df['PIB per capita (R$)'] = df['PIB per capita (R$)'].apply(lambda x: converter_para_float(x))
df['IDH/2000'] = df['IDH/2000'].apply(lambda x: converter_para_float(x))
# Out:
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# imprima novamente as informações das colunas e verifique os tipos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 1 to 121
# Data columns (total 8 columns):
# Município                          104 non-null object
# Estado                             104 non-null object
# Área territorial                   104 non-null float64
# População (IBGE/2007)              104 non-null float64
# Densidade demográfica (hab/km2)    104 non-null float64
# PIB (IBGE/2005                     104 non-null float64
# PIB per capita (R$)                104 non-null float64
# IDH/2000                           104 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 7.3+ KB

# %%
# imprima novamente as primeiras linhas do DataFrame
df.head()
# Out:
#                Município             Estado  Área territorial  \
# 1             Acrelândia               Acre             1.575
# 2                Alecrim  Rio Grande do Sul           315.000
# 3               Almeirim               Pará            72.960
# 4  Alta Floresta d'Oeste           Rondônia             7.067
# 5            Alto Alegre            Roraima            25.567
#
#    População (IBGE/2007)  Densidade demográfica (hab/km2)  PIB (IBGE/2005  \
# 1                 11.520                             7.31     114350000.0
# 2                  7.357                            23.35      44373000.0
# 3                 30.903                             0.42     462258000.0
# 4                 23.857                             3.37     186812000.0
# 5                 14.386                             0.56     115786000.0
#
#    PIB per capita (R$)  IDH/2000
# 1               9986.0     0.680
# 2               5944.0     0.743
# 3              13485.0     0.745
# 4               6525.0     0.715
# 5               5239.0     0.662

# %% [markdown]
# ## EX03

# %% [markdown]
# Crie uma coluna com a sigla dos estados.
#
# * crie um set à partir da coluna Estados. Atribua a uma variável chamada __nomes_estados__.

# %%
# crie o set e verifique o seu conteúdo
nome_estados = {
   "Acre": "AC",
   "Alagoas": "AL",
   "Amapá": "AP",
   "Amazonas": "AM",
   "Bahia": "BA",
   "Ceará": "CE",
   "Distrito Federal": "DF",
   "Espírito Santo": "ES",
   "Goiás": "GO",
   "Maranhão": "MA",
   "Mato Grosso": "MT",
   "Mato Grosso do Sul": "MS",
   "Minas Gerais": "MG",
   "Pará": "PA",
   "Paraíba": "PB",
   "Paraná": "PR",
   "Pernambuco": "PE",
   "Piauí": "PI",
   "Rio de Janeiro": "RJ",
   "Rio Grande do Norte": "RN",
   "Rio Grande do Sul": "RS",
   "Rondônia": "RO",
   "Roraima": "RR",
   "Santa Catarina": "SC",
   "São Paulo": "SP",
   "Sergipe": "SE",
   "Tocantins": "TO"
}

df['nomes_estados'] = df['Estado'].map(nome_estados)
df
# exiba o set gerado
# Out:
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             Município             Estado  Área territorial  \
# 1                          Acrelândia               Acre             1.575
# 2                             Alecrim  Rio Grande do Sul           315.000
# 3                            Almeirim               Pará            72.960
# 4               Alta Floresta d'Oeste           Rondônia             7.067
# 5                         Alto Alegre            Roraima            25.567
# ..                                ...                ...               ...
# 117                         Tunápolis      Santa Cataria           133.000
# 118                          Uiramutã            Roraima             8.066
# 119                        Uruguaiana  Rio Grande do Sul             5.716
# 120  Vila Bela da Santíssima Trindade        Mato Grosso            13.631
# 121                            Xapuri               Acre             5.251
#
#      População (IBGE/2007)  Densidade demográfica (hab/km2)  PIB (IBGE/2005  \
# 1                   11.520                             7.31    1.143500e+08
# 2                    7.357                            23.35    4.437300e+07
# 3                   30.903                             0.42    4.622580e+08
# 4                   23.857                             3.37    1.868120e+08
# 5                   14.386                             0.56    1.157860e+08
# ..                     ...                              ...             ...
# 117                  4.650                            34.96    4.084500e+07
# 118                  7.403                             0.91    2.725100e+07
# 119                123.743                            21.64    1.187038e+09
# 120                 13.886                             1.01    1.169080e+08
# 121                 14.314                             2.72    8.237700e+07
#
#      PIB per capita (R$)  IDH/2000 nomes_estados
# 1                 9986.0     0.680            AC
# 2                 5944.0     0.743            RS
# 3                13485.0     0.745            PA
# 4                 6525.0     0.715            RO
# 5                 5239.0     0.662            RR
# ..                   ...       ...           ...
# 117               9420.0     0.821           NaN
# 118               4238.0     0.542            RR
# 119               8798.0     0.788            RS
# 120               8047.0     0.715            MT
# 121               6016.0     0.669            AC
#
# [104 rows x 9 columns]

# %% [markdown]
# Você identificou um problema no nome dos estados?
# Vamos corrigir no final.
#
# * crie um dicionário onde o nome completo do estado é a chave e a sigla é o valor: __dic_nomes_siglas__

# %%
# crie o dicionário

# %% [markdown]
# * utilize a função map do DataFrame para criar uma nova coluna de siglas à partir dos nomes dos estados. Passe o dicionário criado para a função map. Atribua a Série criada à variável __coluna_siglas_uf__.

# %%
# faça o mapeamento dos valores e atribua a : coluna_siglas_uf


# verifique os 10 primeiros itens criados
df.head()
# Out:
#                Município             Estado  Área territorial  \
# 1             Acrelândia               Acre             1.575
# 2                Alecrim  Rio Grande do Sul           315.000
# 3               Almeirim               Pará            72.960
# 4  Alta Floresta d'Oeste           Rondônia             7.067
# 5            Alto Alegre            Roraima            25.567
#
#    População (IBGE/2007)  Densidade demográfica (hab/km2)  PIB (IBGE/2005  \
# 1                 11.520                             7.31     114350000.0
# 2                  7.357                            23.35      44373000.0
# 3                 30.903                             0.42     462258000.0
# 4                 23.857                             3.37     186812000.0
# 5                 14.386                             0.56     115786000.0
#
#    PIB per capita (R$)  IDH/2000 nomes_estados
# 1               9986.0     0.680            AC
# 2               5944.0     0.743            RS
# 3              13485.0     0.745            PA
# 4               6525.0     0.715            RO
# 5               5239.0     0.662            RR

# %%
# verifique quantos registros possuem o nome do estado de Santa Catarina escrito errado "Santa Cataria"
df.loc[df.Estado == 'Santa Cataria']
len(df.loc[df.Estado == 'Santa Cataria'])
# Out:
# 1

# %%
# faça a correção dos registros que possuem o nome do estado de Santa Catarina escrito errado
df.loc[df.Estado == 'Santa Cataria', 'Estado'] = 'Santa Catarina'
# Out:
# /home/dev/.local/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# verifique, novamente, quantos registros possuem o nome do estado de Santa Catarina escrito errado
df.loc[df.Estado == 'Santa Cataria']
# Out:
# Empty DataFrame
# Columns: [Município, Estado, Área territorial, População (IBGE/2007), Densidade demográfica (hab/km2), PIB (IBGE/2005, PIB per capita (R$), IDH/2000, nomes_estados]
# Index: []

# %% [markdown]
# ## EX04
#
# Identifique quais municípios possuem 2 ou mais desvios na coluna PIB.

# %%
# normalize a coluna PIB em quantidade de desvios padrão
df['pib_normal'] = (df['PIB (IBGE/2005'] - df['PIB (IBGE/2005'].mean()) / df['PIB (IBGE/2005'].std()
# exiba um histograma para as informações de PIB normalizado
sns.distplot(df['pib_normal'])
# Out:
# /home/dev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# quais cidades possuem mais de 2 desvios 
df.loc[df['pib_normal'] > 2]
# Out:
#         Município              Estado  Área territorial  \
# 33        Corumbá  Mato Grosso do Sul            65.304
# 45  Foz do Iguaçu              Paraná           618.000
# 89    Porto Velho            Rondônia            34.082
#
#     População (IBGE/2007)  Densidade demográfica (hab/km2)  PIB (IBGE/2005  \
# 33                114.279                             1.74    1.557253e+09
# 45                311.336                           503.70    4.853331e+09
# 89                369.345                            10.83    3.656512e+09
#
#     PIB per capita (R$)  IDH/2000 nomes_estados  pib_normal
# 33              13234.0     0.771            MS    2.116544
# 45              16102.0     0.802            PR    7.432403
# 89               9779.0     0.763            RO    5.502194

# %% [markdown]
# ## EX05
#
# Perguntas rápidas.

# %%
# quantos registros possuem NaN na coluna IDH/2000?
# R: Anteriormente o professor solicitou deletar todos os NaN nessa coluna, mas era de 122

# %%
# quantas cidades por estado?
df.groupby(['Estado'])['Município'].count()
# Out:
# Estado
# Acre                  17
# Amazonas               1
# Mato Grosso            5
# Mato Grosso do Sul    12
# Paraná                17
# Pará                   3
# Rio Grande do Sul     27
# Rondônia               5
# Roraima                9
# Santa Catarina         8
# Name: Município, dtype: int64

# %%
# faça a ordenação do DataFrame pelo nome do município
df.sort_values(by='Município')

# a ordenação está correta?
#Não. A cidade de Óbidos, acentuada, ficou incorretame
# Out:
#                             Município              Estado  Área territorial  \
# 1                          Acrelândia                Acre             1.575
# 2                             Alecrim   Rio Grande do Sul           315.000
# 3                            Almeirim                Pará            72.960
# 4               Alta Floresta d'Oeste            Rondônia             7.067
# 5                         Alto Alegre             Roraima            25.567
# 7                             Amajari             Roraima            28.472
# 8                        Antônio João  Mato Grosso do Sul             1.144
# 9                        Aral Moreira  Mato Grosso do Sul             1.656
# 10                       Assis Brasil                Acre             2.876
# 12                               Bagé   Rio Grande do Sul             4.096
# 13                        Bandeirante      Santa Catarina           146.000
# 15                    Barra do Quaraí   Rio Grande do Sul             1.056
# 16                           Barracão              Paraná           164.000
# 17                         Bela Vista  Mato Grosso do Sul             4.896
# 18                           Belmonte      Santa Catarina            94.000
# 20                   Bom Jesus do Sul              Paraná           174.000
# 21                             Bonfim             Roraima             8.095
# 22                          Brasiléia                Acre             4.336
# 23                             Cabixi            Rondônia             1.314
# 25                           Capanema              Paraná           419.000
# 26                           Capixaba                Acre             1.713
# 27                          Caracaraí             Roraima            47.411
# 28                            Caracol  Mato Grosso do Sul             2.939
# 29                            Caroebe             Roraima            12.066
# 30                               Chuí   Rio Grande do Sul           203.000
# 31                           Comodoro         Mato Grosso            21.743
# 32                   Coronel Sapucaia  Mato Grosso do Sul             1.029
# 33                            Corumbá  Mato Grosso do Sul            65.304
# 35                         Crissiumal   Rio Grande do Sul           362.000
# 36                    Cruzeiro do Sul                Acre             7.925
# ..                                ...                 ...               ...
# 89                        Porto Velho            Rondônia            34.082
# 90                    Porto Vera Cruz   Rio Grande do Sul           114.000
# 91                       Porto Walter                Acre             6.136
# 92                       Porto Xavier   Rio Grande do Sul           281.000
# 93                          Pranchita              Paraná           226.000
# 78                     Pérola d'Oeste              Paraná           206.000
# 95                             Quaraí   Rio Grande do Sul             3.148
# 96                    Rodrigues Alves                Acre             3.305
# 97                     Roque Gonzales   Rio Grande do Sul           347.000
# 98                       Santa Helena              Paraná           758.000
# 99                       Santa Helena      Santa Catarina            81.000
# 101               Santa Rosa do Purus                Acre             5.981
# 102           Santa Vitória do Palmar   Rio Grande do Sul             5.244
# 103             Santana do Livramento   Rio Grande do Sul             6.950
# 105         Santo Antônio do Sudoeste              Paraná           326.000
# 112                    Sena Madureira                Acre            25.278
# 113            Serranópolis do Iguaçu              Paraná           484.000
# 114                       Sete Quedas  Mato Grosso do Sul           826.000
# 106                         São Borja   Rio Grande do Sul             3.616
# 108          São Gabriel da Cachoeira            Amazonas           109.185
# 109                 São José do Cedro      Santa Catarina           280.000
# 110              São Miguel do Iguaçu              Paraná           851.000
# 111                       São Nicolau   Rio Grande do Sul           485.000
# 116                 Tiradentes do Sul   Rio Grande do Sul           234.000
# 117                         Tunápolis      Santa Catarina           133.000
# 118                          Uiramutã             Roraima             8.066
# 119                        Uruguaiana   Rio Grande do Sul             5.716
# 120  Vila Bela da Santíssima Trindade         Mato Grosso            13.631
# 121                            Xapuri                Acre             5.251
# 70                             Óbidos                Pará            28.021
#
#      População (IBGE/2007)  Densidade demográfica (hab/km2)  PIB (IBGE/2005  \
# 1                   11.520                             7.31    1.143500e+08
# 2                    7.357                            23.35    4.437300e+07
# 3                   30.903                             0.42    4.622580e+08
# 4                   23.857                             3.37    1.868120e+08
# 5                   14.386                             0.56    1.157860e+08
# 7                    7.586                             0.26    3.189700e+04
# 8                    8.350                             7.29    3.998900e+07
# 9                    9.236                             5.57    1.056970e+08
# 10                   5.351                             1.86    3.029800e+07
# 12                 112.550                            27.47    9.064880e+08
# 13                   3.028                            20.73    2.142300e+07
# 15                   3.776                             3.57    6.154000e+07
# 16                   9.027                            55.04    6.060100e+07
# 17                  22.868                             4.67    1.328700e+08
# 18                   2.681                            28.52    2.167000e+07
# 20                   3.835                            22.04    1.795000e+07
# 21                  10.231                             1.26    6.836300e+07
# 22                  19.065                             4.39    1.175250e+08
# 23                   6.575                             5.00    7.712500e+07
# 25                  18.103                            43.20    1.805190e+08
# 26                   8.446                             4.93    7.838900e+07
# 27                  17.981                             0.37    1.008850e+08
# 28                   5.095                             1.73    4.553300e+07
# 29                   7.086                             0.58    4.229600e+07
# 30                   5.278                            26.00    6.752500e+07
# 31                  17.939                             0.82    1.699190e+08
# 32                  13.979                            13.58    5.479700e+07
# 33                 114.279                             1.74    1.557253e+09
# 35                  14.726                            40.67    1.140890e+08
# 36                  73.948                             9.33    3.919430e+08
# ..                     ...                              ...             ...
# 89                 369.345                            10.83    3.656512e+09
# 90                   2.084                            18.28    1.417800e+07
# 91                   8.170                             1.33    2.592500e+07
# 92                  10.857                            38.63    7.133700e+07
# 93                   5.811                            25.71    5.733100e+07
# 78                   7.046                            34.20    4.578100e+07
# 95                  22.552                             7.16    1.624120e+08
# 96                  12.428                             3.76    5.146800e+07
# 97                   7.297                            21.02    5.465500e+07
# 98                  22.794                            30.07    2.199730e+08
# 99                   2.437                            30.08    1.654490e+08
# 101                  3.948                             0.66    1.532100e+07
# 102                 31.183                             5.94    2.892230e+08
# 103                 83.479                            12.01    5.983870e+08
# 105                 18.565                            56.94    9.252100e+07
# 112                 34.230                             1.35    2.343810e+08
# 113                  4.327                             8.94    5.287600e+07
# 114                 10.659                            12.90    5.410300e+07
# 106                 65.671                            17.10    5.968040e+08
# 108                 39.129                             0.35    1.110930e+08
# 109                 13.699                            48.92    1.537220e+08
# 110                 25.341                            29.77    2.973000e+08
# 111                  5.909                            12.18    3.233800e+07
# 116                  6.928                            29.60    4.292600e+07
# 117                  4.650                            34.96    4.084500e+07
# 118                  7.403                             0.91    2.725100e+07
# 119                123.743                            21.64    1.187038e+09
# 120                 13.886                             1.01    1.169080e+08
# 121                 14.314                             2.72    8.237700e+07
# 70                  46.793                             1.66    1.384890e+08
#
#      PIB per capita (R$)  IDH/2000 nomes_estados
# 1                 9986.0     0.680            AC
# 2                 5944.0     0.743            RS
# 3                13485.0     0.745            PA
# 4                 6525.0     0.715            RO
# 5                 5239.0     0.662            RR
# 7              5240000.0     0.654            RR
# 8                 5067.0     0.702            MS
# 9                13132.0     0.723            MS
# 10                5984.0     0.670            AC
# 12                7473.0     0.802            RS
# 13                7546.0     0.765            SC
# 15               14429.0     0.777            RS
# 16                6718.0     0.764            PR
# 17                5676.0     0.755            MS
# 18                9954.0     0.759            SC
# 20                4638.0     0.696            PR
# 21                5414.0     0.654            RR
# 22                6632.0     0.669            AC
# 23               10372.0     0.705            RO
# 25               10297.0     0.803            PR
# 26               11092.0     0.607            AC
# 27                5685.0     0.702            RR
# 28                9094.0     0.725            MS
# 29                7207.0     0.661            RR
# 30               10574.0     0.811            RS
# 31                9010.0     0.724            MT
# 32                4041.0     0.713            MS
# 33               13234.0     0.771            MS
# 35                8376.0     0.786            RS
# 36                4647.0     0.668            AC
# ..                   ...       ...           ...
# 89                9779.0     0.763            RO
# 90                6378.0     0.755            RS
# 91                5225.0     0.540            AC
# 92                6285.0     0.762            RS
# 93               10120.0     0.803            PR
# 78                6961.0     0.759            PR
# 95                6444.0     0.776            RS
# 96                5254.0     0.550            AC
# 97                7626.0     0.749            RS
# 98               10226.0     0.799            PR
# 99               14812.0     0.787            SC
# 101               4513.0     0.525            AC
# 102               8360.0     0.799            RS
# 103               6138.0     0.803            RS
# 105               5101.0     0.715            PR
# 112               7105.0     0.652            AC
# 113              10635.0     0.796            PR
# 114               6445.0     0.719            MS
# 106               8862.0     0.798            RS
# 108               3261.0     0.567            AM
# 109              11838.0     0.804            SC
# 110              11065.0     0.779            PR
# 111               5290.0     0.713            RS
# 116               6577.0     0.746            RS
# 117               9420.0     0.821           NaN
# 118               4238.0     0.542            RR
# 119               8798.0     0.788            RS
# 120               8047.0     0.715            MT
# 121               6016.0     0.669            AC
# 70                2820.0     0.681            PA
#
# [104 rows x 9 columns]
